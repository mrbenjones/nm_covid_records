# %%
import json
import datetime
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


def collected(jsonFile):

    entries = json.load(open(jsonFile))["data"]
    r = [ {
        "dataDate": t['date'],
        "cases": t['cases'],
        "deaths": t['deaths'],
        "tests": t['tests']
        } for t in entries]
    r.sort( key=lambda x:x['dataDate'])

    windows = [
        {'date': r[i]['dataDate'],
         'cases': max(r[i]['cases']-r[i-7]['cases'],0),
         'tests': max(r[i]['tests']-r[i-7]['tests'],0),
         'deaths': r[i]['deaths']
         }
        for i in range(7,len(r))
        ]

    windows = [{
        'date' : w['date'],
        'cases' : w['cases'],
        'tests' : w['tests'],
        'deaths' : w['deaths'],
        'pos' : w['cases']/w['tests'] if (w['tests']) else 0
        }
        for w in windows
        ]
    windows = [
        {
            'date' : w['date'],
            'pos': w['pos'],
            'deaths' : w['deaths'],
            'estimate' : 28*w['cases']*math.sqrt(max(w['pos'],0.0))     
        }
        for w in windows
        ]
    windows = [
        {
        'date': w['date'],
        'pos': w['pos'],
            'deaths' : w['deaths'],
        'estimate': w['estimate']
        }
        for w in windows
        ]
    return windows

# %%
data=collected('../downloads/2020_8_21/lea.json')

# %%
plt.plot([w['pos'] for w in data])

# %%
plt.plot([w['estimate'] for w in data])

# %%
total = sum(l['estimate'] for l in data)/10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e1aef680679e> in <module>
# ----> 1 total = sum(l['estimate'] for l in data)/10
#
# NameError: name 'data' is not defined

# %%
print(total,data[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a9eaec2fefb7> in <module>
# ----> 1 print(total,data[0])
#
# NameError: name 'total' is not defined
